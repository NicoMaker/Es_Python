# %% [markdown]
# # Circuito RC

# %%
import numpy as np
from matplotlib import pyplot as plt

#Importa i limiti di visualizzazione del grafico
plt.xlim(-3,3)
plt.ylim(-1,1)

#Imposto qualche punto
x = np.linspace(-(2*np.pi),2*np.pi,100)
y = np.sin(x)

plt.plot(x,y,marker = "o", color = "green")

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.figure()

ax = plt.axes(projection = '3d')

z = np.linspace(0,1,100)
x = z * np.sin(25*z)
y = z * np.cos(25*z)

ax.scatter(x,y,z)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

#Importa i limiti di visualizzazione del grafico
plt.xlim(-1,10)
plt.ylim(-1e6,1e6)

#Imposto qualche punto
n = 10
k = -1e5
p0 = 1e-5
x = np.linspace(0,1,100)
ptn = (1+k*t/n)**n*p0

plt.plot(x,y,marker = "o", color = "green")

# %%
import numpy as np
from matplotlib import pyplot as plt

budget_totale = 3e6
x = budget_totale

#Insuccessi:
Progetto_A = 0.3
Progetto_B = 0.2

budgetA = 0
for budgetB in range(int(budget_totale)+1):
    minimo = budgetB + budgetA
    if minimo < budget_totale:
        x = minimo
else:
    print(x)


for budgetB in range(int(budget_totale)+1):
    minimo = (budget_totale-budgetB) * Progetto_A + budgetB * Progetto_B
    
    if minimo <= budget_totale:
        x = minimo
        
else:
    print(x)
# Out:
# 2999999
# 600000.0

# %%
#Dichiarazioni costanti:
rischioA = 0.3
rischioB = 0.2
budget = 3e6
x = budget

#Calcolo del rischio totale:
for progettoB in range(int(budget)+1):
    rischio_tot = (budget - progettoB) * rischioA + progettoB * rischioB
    
    if rischio_tot <= x:
        x = rischio_tot
        progettoAx = budget - progettoB
        progettoBx = progettoB

else:
    print(f"Il valore minimo raggiunto è: {x}€ con rispettivi valori dei progetti")
    print(f"ProgettoA :{progettoAx}, ProgettoB: {progettoBx}")
# Out:
# Il valore minimo raggiunto è: 600000.0€ con rispettivi valori dei progetti
# ProgettoA :0.0, ProgettoB: 3000000

# %%
xc -= 1.3335
xl = 1.4827
xp = 0
xo = -0.2431

xc = 1
xl = 1
xp = 1
xo = 1

lim_grassi = 30
lim_carboidrati = 90
lim_proteine = 60

arrGrassi = [2.6, 1.5, 1.5, 100]
arrCarboidrati = [0, 60.7, 74.7, 0]
arrProteine = [20.2, 22.3, 13.0, 0]

grassi = xc * 2.6 + xl * 1.5 + xp * 1.5 + xo * 100
legumi = xc * 0 + xl * 60.7 + xp * 74.7 + xo * 0
proteine = xc * 20.2 + xl * 22.3 + xp * 13.0 + xo * 0

print(grassi)
print(legumi)
print(proteine)

index = 0
for n in arrGrassi:
    xc = legumi -(xl * 60.7 + xp * 74.7 + xo * 0)
    print(arrGrassi[index])
    index += 1
# Out:
# 105.6
# 135.4
# 55.5
# 2.6
# 1.5
# 1.5
# 100
# 1062.0

# %%
contenitore = 120
peso_biscotto = [20,25,26,21,36,28,28,27,23]
perc_cioccolato = [32,58,65,18,28,55,40,40,25]
list1 = []
index = 0
contenuto_iniziale = 0
cioccolato_iniziale = 0
for n in peso_biscotto:
    contenuto_finale = int(contenitore/peso_biscotto[index])
    
    list1.append(contenuto_finale)

    if contenuto_iniziale < contenuto_finale and cioccolato_iniziale < perc_cioccolato[index]:
        contenuto_iniziale = contenuto_finale
        cioccolato_iniziale = index
    index += 1
print("Numero biscotti nel contenitore:")
print(list1)

print(f"Il numero massimo di biscotti nel contenitore è: {contenuto_iniziale}")
print(f"La massima percentuale di cioccolato è: {perc_cioccolato[cioccolato_iniziale]}")
# Out:
# Numero biscotti nel contenitore:
# [6, 4, 4, 5, 3, 4, 4, 4, 5]
# Il numero massimo di biscotti nel contenitore è: 6
# La massima percentuale di cioccolato è: 32
